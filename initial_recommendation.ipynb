# %%
import pandas as pd
import numpy as np

anime_cols = ['anime_id', 'name', 'genre', 'type', 'episodes', 'rating']
anime = pd.read_csv('/Users/brangmai/Desktop/Capstone/modified_data/anime.csv', names=anime_cols, usecols=range(6), encoding="ISO-8859-1")
anime = anime[1:]
anime = pd.DataFrame(anime)
anime.head(-20)
#print(len(anime))
# Out:
#       anime_id                                               name  \
# 1            1                                       Cowboy Bebop
# 2            5                    Cowboy Bebop: Tengoku no Tobira
# 3            6                                             Trigun
# 4            7                                 Witch Hunter Robin
# 5            8                             Beet the Vandel Buster
# ...        ...                                                ...
# 12270      763                                              Zoids
# 12271     7953                                        Defend Love
# 12272     7981                            Obake no Q-tarou (1985)
# 12273     8134  Keroro Gunsou Movie 5: Tanjou! Kyuukyoku Keror...
# 12274     8229                     on-chan, Yume Power Daibouken!
#
#                                                    genre     type episodes  \
# 1        Action, Adventure, Comedy, Drama, Sci-Fi, Space       TV       26
# ...

# %% [markdown]
# # The highest rated animes from all type

# %%
highest_rated_animes = anime.sort_values(by='rating', ascending=False)
highest_rated_animes = highest_rated_animes.head(10)

highest_rated_animes.reset_index(drop=True, inplace=True)
cols = list(highest_rated_animes.columns.values)

highest_rated_animes = highest_rated_animes[cols[1:4] + [cols[-1]]]

#highiest_rated_animes.style.set_properties(subset=['name'], **{'text-align': 'left'})
highest_rated_animes.head(50)

# for index, row in highiest_rated_animes.iterrows():
#     print((index + 1), row['name'], row['genre'])
# Out:
#                                                 name  \
# 0                        Spoon-hime no Swing Kitchen
# 1                                   Mogura no Motoro
# 2                                     Kimi no Na wa.
# 3                                       Kahei no Umi
# 4                   Fullmetal Alchemist: Brotherhood
# 5                    Yakusoku: Africa Mizu to Midori
# 6                                            Gintama
# 7                                        Steins;Gate
# 8                                           Gintama
# 9  Haikyuu!!: Karasuno Koukou VS Shiratorizawa Ga...
#
#                                                genre   type rating
# 0                                    Adventure, Kids     TV    9.6
# 1                                      Slice of Life  Movie    9.5
# 2               Drama, Romance, School, Supernatural  Movie   9.37
# 3                                         Historical  Movie   9.33
# ...

# %% [markdown]
# # The highest rated movies

# %%
anime_movies = anime.loc[anime['type'] == 'Movie']
anime_movies = anime_movies.sort_values(by='rating', ascending=False)
anime_movies.reset_index(drop=True, inplace=True)
cols = list(anime_movies.columns.values)
anime_movies = anime_movies[cols[1:3] + [cols[-1]]]
anime_movies.head(10)
# Out:
#                                                 name  \
# 0                                   Mogura no Motoro
# 1                                     Kimi no Na wa.
# 2                                       Kahei no Umi
# 3  Gintama Movie: Kanketsu-hen - Yorozuya yo Eien...
# 4                                     Koe no Katachi
# 5                            Shenmi Shijie Lixian Ji
# 6                                  Okaachan Gomen ne
# 7                Mirai ni Mukete: Bousai wo Kangaeru
# 8                                   Shaka no Shougai
# 9                      Sen to Chihiro no Kamikakushi
#
#                                                genre rating
# 0                                      Slice of Life    9.5
# 1               Drama, Romance, School, Supernatural   9.37
# 2                                         Historical   9.33
# 3  Action, Comedy, Historical, Parody, Samurai, S...    9.1
# 4                             Drama, School, Shounen   9.05
# ...

# %% [markdown]
# # The highest rated TV-series

# %%
anime_tv = anime.loc[anime['type'] == 'TV']
anime_tv = anime_tv.sort_values(by='rating', ascending=False)
anime_tv.reset_index(drop=True, inplace=True)

cols = list(anime_tv.columns.values)
anime_tv = anime_tv[cols[1:3] + [cols[-1]]]
anime_tv.head(10)
# Out:
#                                                 name  \
# 0                        Spoon-hime no Swing Kitchen
# 1                   Fullmetal Alchemist: Brotherhood
# 2                                            Gintama
# 3                                        Steins;Gate
# 4                                           Gintama
# 5  Haikyuu!!: Karasuno Koukou VS Shiratorizawa Ga...
# 6                             Hunter x Hunter (2011)
# 7                                Gintama : Enchousen
# 8                               Clannad: After Story
# 9                                            Gintama
#
#                                                genre rating
# 0                                    Adventure, Kids    9.6
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...   9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...   9.25
# 3                                   Sci-Fi, Thriller   9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...   9.16
# ...

# %% [markdown]
# # The highest rated original video animation (neither movies nor tv )

# %%
anime_others = anime.loc[(anime['type'] != 'Movie') & (anime['type'] != 'TV')]
anime_others = anime_others.sort_values(by='rating', ascending=False)
anime_others.reset_index(drop=True, inplace=True)

cols = list(anime_others.columns.values)
anime_others = anime_others[cols[1:3] + [cols[-1]]]
anime_others.head(10)
# Out:
#                                                 name  \
# 0                    Yakusoku: Africa Mizu to Midori
# 1                               Ginga Eiyuu Densetsu
# 2          Mienu Me ni Kanjita Kumotoriyama no Asahi
# 3                          Santa-san wa Dai Isogashi
# 4  Rurouni Kenshin: Meiji Kenkaku Romantan - Tsui...
# 5                          Gintama: Aizome Kaori-hen
# 6                                    Yume no Tsuzuki
# 7                Kie Saranu Kizuato: Hi no Umi Osaka
# 8  Yamete! Writer Asobi: Doubutsu Mura no Shoubou...
# 9                                   Minna no Doutoku
#
#                                                genre rating
# 0                                        Drama, Kids   9.25
# 1                     Drama, Military, Sci-Fi, Space   9.11
# 2                                        Drama, Kids      9
# 3                                      Fantasy, Kids      9
# 4  Action, Drama, Historical, Martial Arts, Roman...   8.83
# ...
