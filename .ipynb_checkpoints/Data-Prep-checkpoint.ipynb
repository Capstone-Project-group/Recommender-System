# %%
import pandas as pd

rating_cols = ['user_id', 'anime_id', 'rating']
ratings = pd.read_csv('/Users/brangmai/Desktop/Capstone/modified_data/rating.csv', names=rating_cols, usecols=range(3), encoding="ISO-8859-1")
ratings = ratings[1:]


anime_cols = ['anime_id', 'name', 'genre']
anime = pd.read_csv('/Users/brangmai/Desktop/Capstone/modified_data/anime.csv', names=anime_cols, usecols=range(3), encoding="ISO-8859-1")
anime = anime[1:]

anime_ratings = pd.merge(anime, ratings)
anime_ratings.tail()
# Out:
# /Users/brangmai/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (0,1,2) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        anime_id                               name         genre user_id  \
# 262138     1639                       Boku no Pico  Hentai, Yaoi    2675
# 262139     1639                       Boku no Pico  Hentai, Yaoi    2698
# 262140     1639                       Boku no Pico  Hentai, Yaoi    2710
# 262141    23171  Mahou Shoujo wa Kiss Shite Kawaru        Hentai     201
# 262142     5545       Heisei Jogakuen Kagai Lesson        Hentai    2594
#
#        rating
# 262138     -1
# 262139      2
# 262140      5
# 262141     -1
# 262142      3

# %%
print(ratings.shape)
print(ratings.columns)
ratings.head()
# Out:
# (7813737, 3)
# Index(['user_id', 'anime_id', 'rating'], dtype='object')
#   user_id anime_id rating
# 1       1       20     -1
# 2       1       24     -1
# 3       1       79     -1
# 4       1      226     -1
# 5       1      241     -1

# %%
anime_genre = anime['genre'].values.tolist()
genre = set()
for gen in anime_genre:
    for g in gen:
        genre.add(g)
for gen in genre:
    print(gen)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/rt/ggn8jbgx17l3ym1h3whzgr2c0000gn/T/ipykernel_37005/4282403185.py in <module>
#       2 genre = set()
#       3 for gen in anime_genre:
# ----> 4     for g in gen:
#       5         genre.add(g)
#       6 for gen in genre:
#
# TypeError: 'float' object is not iterable

# %%
import matplotlib.pyplot as plt

plt.rc("font", size=15)
ratings.rating.value_counts(sort=False).plot(kind='bar')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()

# %%
print(anime.shape)
print(list(anime.columns))
anime.head()
# Out:
# (12294, 3)
# ['anime_id', 'name', 'genre']
#   anime_id                              name  \
# 1    32281                    Kimi no Na wa.
# 2     5114  Fullmetal Alchemist: Brotherhood
# 3    28977                         GintamaÂ°
# 4     9253                       Steins;Gate
# 5     9969                     Gintama&#039;
#
#                                                genre
# 1               Drama, Romance, School, Supernatural
# 2  Action, Adventure, Drama, Fantasy, Magic, Mili...
# 3  Action, Comedy, Historical, Parody, Samurai, S...
# 4                                   Sci-Fi, Thriller
# 5  Action, Comedy, Historical, Parody, Samurai, S...

# %%
rating_count = pd.DataFrame(ratings.groupby('anime_id')['rating'].count())
rating_count.sort_values('rating', ascending=False).head()
# Out:
#           rating
# anime_id
# 1535       37917
# 11757      29061
# 16498      28058
# 1575       26779
# 226        26536

# %%
# anime_ratings.describe()

# anime_ratings.loc[anime_ratings['genre'] == 'Hentai'].head(10)

anime_ratings = anime_ratings.pivot_table(index=['user_id'], columns=['name'], values='rating')

anime_ratings.tail()
# Out:
# name     &quot;Bungaku Shoujo&quot; Kyou no Oyatsu: Hatsukoi  \
# user_id
# 995                                                    NaN
# 996                                                    NaN
# 997                                                    NaN
# 998                                                    NaN
# 999                                                    NaN
#
# name     &quot;Bungaku Shoujo&quot; Memoire  &quot;Bungaku Shoujo&quot; Movie  \
# user_id
# 995                                     NaN                               NaN
# 996                                     NaN                               NaN
# 997                                     NaN                               NaN
# 998                                     NaN                               NaN
# 999                                     NaN                               NaN
#
# name     .hack//G.U. Returner  .hack//G.U. Trilogy  \
# user_id
# 995                       NaN                  NaN
# 996                       NaN                  NaN
# 997                       NaN                  NaN
# 998                       NaN                  NaN
# 999                       NaN                  NaN
#
# name     .hack//G.U. Trilogy: Parody Mode  .hack//Gift  .hack//Intermezzo  \
# user_id
# 995                                   NaN          NaN                NaN
# 996                                   NaN          NaN                NaN
# 997                                   NaN          NaN                NaN
# 998                                   NaN          NaN                NaN
# 999                                   NaN          NaN                NaN
#
# name     .hack//Liminality  .hack//Quantum  ...  gdgd Fairies 2  \
# user_id                                     ...
# 995                    NaN             NaN  ...             NaN
# 996                    NaN             NaN  ...             NaN
# 997                    NaN             NaN  ...             NaN
# 998                    NaN             NaN  ...             NaN
# 999                    NaN             NaN  ...             NaN
#
# name     gdgd Fairies Movie: tte Iu Eiga wa Dou kana...?  \
# user_id
# 995                                                  NaN
# 996                                                  NaN
# 997                                                  NaN
# 998                                                  NaN
# 999                                                  NaN
#
# name     iDOLM@STER Xenoglossia  iDOLM@STER Xenoglossia Specials  s.CRY.ed  \
# user_id
# 995                         NaN                              NaN       NaN
# 996                         NaN                              NaN       NaN
# 997                         NaN                              NaN       NaN
# 998                         NaN                              NaN       NaN
# 999                         NaN                              NaN       NaN
#
# name     xxxHOLiC  xxxHOLiC Kei  xxxHOLiC Movie: Manatsu no Yoru no Yume  \
# user_id
# 995           NaN           NaN                                      NaN
# 996           NaN           NaN                                      NaN
# 997           NaN           NaN                                      NaN
# 998           NaN           NaN                                      NaN
# 999           NaN           NaN                                      NaN
#
# name     xxxHOLiC Rou  xxxHOLiC Shunmuki
# user_id
# 995               NaN                NaN
# 996               NaN                NaN
# 997               NaN                NaN
# 998               NaN                NaN
# 999               NaN                NaN
#
# [5 rows x 6317 columns]

# %%
bokunopico_ratings = anime_ratings['Boku no Pico']
bokunopico_ratings.head()
# Out:
# user_id
# 1      NaN
# 10     NaN
# 100    NaN
# 1000   NaN
# 1001   NaN
# Name: Boku no Pico, dtype: float64

# %%
similar_anime = anime_ratings.corrwith(bokunopico_ratings)
similar_anime = similar_anime.dropna()
df = pd.DataFrame(similar_anime)
df.head(10)
# Out:
# /Users/brangmai/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/function_base.py:2634: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# /Users/brangmai/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/function_base.py:2493: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)
#                                          0
# name
# &quot;Bungaku Shoujo&quot; Movie -0.500000
# .hack//G.U. Returner              1.000000
# .hack//Gift                       0.786742
# .hack//Liminality                 0.786742
# .hack//Quantum                   -0.866025
# .hack//Roots                     -0.710742
# .hack//Sign                       0.544159
# 07-Ghost                          0.146616
# 11eyes                           -0.233462
# 11eyes: Momoiro Genmutan         -0.064948

# %%
similar_anime.sort_values(ascending=False)
# Out:
# name
# Nanairo Kakumei                                      1.0
# Ristorante Paradiso                                  1.0
# OnegaiâTeacher: Himitsu na Futari                  1.0
# Mobile Suit Gundam Wing                              1.0
# Suzuka                                               1.0
#                                                     ...
# Metal Fight Beyblade 4D                             -1.0
# Alps no Shoujo Heidi                                -1.0
# Mariaâ Holic Alive Special                         -1.0
# Maken-Ki! Specials                                  -1.0
# Prince of Tennis: The Two Samurai, The First Game   -1.0
# Length: 1977, dtype: float64

# %%
import numpy as np

anime_stats = anime_ratings.groupby('anime_id').agg({'genre'})
anime_stats.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/rt/ggn8jbgx17l3ym1h3whzgr2c0000gn/T/ipykernel_34940/1428552391.py in <module>
#       1 import numpy as np
#       2
# ----> 3 anime_stats = anime_ratings.groupby('anime_id').agg({'genre'})
#       4 anime_stats.head()
#
# NameError: name 'anime_ratings' is not defined
